# %% [markdown]
# # AI Ethics Hackathon
#
# ## NYPD Complaints 1985 - 2020
#
# The problem: **Predictive policing**
#
# If you train a model on biased data (data where systemic discrimination is deeply rooted) then you well get biased predictions that will perpetuate discrimination by law enforcement. The use of predictive policing can also contribute to further accountability by police officers via [tech-washing](https://www.brennancenter.org/our-work/research-reports/predictive-policing-explained).
#
# So is there a place for predictive policing?
#
# ----
#
# Well, what is the purpose of predictive policing?
#
# - forecasting crime
#
# and the purpose of forecasting crime or any sort of policing?
#
# [Wikipedia](https://en.wikipedia.org/wiki/Police): "The police are a constituted body of persons empowered by a state, with the aim to enforce the law, **to ensure the safety, health and possessions of citizens**, and to prevent crime and civil disorder."
#
# [Charles Koch Institute](https://www.charleskochinstitute.org/issue-areas/criminal-justice-policing-reform/role-of-police-in-america/): "The purpose of law enforcement in a free society is to promote public safety and uphold the rule of law so that individual liberty may flourish. Trust and **accountability** between law enforcement and the communities they are sworn to protect is essential to advancing these goals."
#
# - To serve and protect
#
# With the growth of technology so has the awareness of police brutality and the disproportionate harm (often with a lack of police accountability) to Black Americans.
#
# **In that sense, if the purpose of predictive policing at the highest level is to protect citizens then maybe instead we should determine where (precincts) officers are harming citizens ("hotspots") and whether they will be held accountable.**

# %% [markdown]
# In this notebook we will be cleaning and completing EDA on a database of more than 12,000 civilian complaints filed against New York City police officers. https://www.propublica.org/datastore/dataset/civilian-complaints-against-new-york-city-police-officers

# %%
# Imports
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# https://theintercept.com/2020/08/23/nypd-75th-precinct-police-misconduct/

# %% [markdown]
# ## Cleaning
#
# Let's start by reading in the dataset.

# %%
# Read csv as a dataframe
df_raw = pd.read_csv('CCRB-Complaint-Data_202007271729/allegations_202007271729.csv')

# Print the shape of the raw df 
print(f'The dataframe has {df_raw.shape[0]} rows and {df_raw.shape[1]} columns. \n')

# Checking out first 5 rows
df_raw.head()
# Out:
# The dataframe has 33358 rows and 27 columns.
#    unique_mos_id first_name last_name command_now  shield_no  complaint_id  \
# 0          10004   Jonathan      Ruiz     078 PCT       8409         42835
# 1          10007       John     Sears     078 PCT       5952         24601
# 2          10007       John     Sears     078 PCT       5952         24601
# 3          10007       John     Sears     078 PCT       5952         26146
# 4          10009      Noemi    Sierra     078 PCT      24058         40253
#
#    month_received  year_received  month_closed  year_closed  ...  \
# 0               7           2019             5         2020  ...
# 1              11           2011             8         2012  ...
# 2              11           2011             8         2012  ...
# 3               7           2012             9         2013  ...
# 4               8           2018             2         2019  ...
#
#   mos_age_incident complainant_ethnicity complainant_gender  \
# 0               32                 Black             Female
# 1               24                 Black               Male
# 2               24                 Black               Male
# 3               25                 Black               Male
# 4               39                   NaN                NaN
#
#   complainant_age_incident           fado_type                    allegation  \
# 0                     38.0  Abuse of Authority  Failure to provide RTKA card
# 1                     26.0         Discourtesy                        Action
# 2                     26.0  Offensive Language                          Race
# 3                     45.0  Abuse of Authority                      Question
# 4                     16.0               Force                Physical force
#
#   precinct                                contact_reason  \
# 0     78.0                       Report-domestic dispute
# 1     67.0                              Moving violation
# 2     67.0                              Moving violation
# 3     67.0  PD suspected C/V of violation/crime - street
# 4     67.0                                Report-dispute
#
#                 outcome_description                         board_disposition
# 0  No arrest made or summons issued  Substantiated (Command Lvl Instructions)
# 1   Moving violation summons issued                   Substantiated (Charges)
# 2   Moving violation summons issued                   Substantiated (Charges)
# 3  No arrest made or summons issued                   Substantiated (Charges)
# 4    Arrest - other violation/crime      Substantiated (Command Discipline A)
#
# [5 rows x 27 columns]

# %% [markdown]
# Let's learn more about each column, their datatypes and get an initial feel for any missing data.

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33358 entries, 0 to 33357
# Data columns (total 27 columns):
# unique_mos_id               33358 non-null int64
# first_name                  33358 non-null object
# last_name                   33358 non-null object
# command_now                 33358 non-null object
# shield_no                   33358 non-null int64
# complaint_id                33358 non-null int64
# month_received              33358 non-null int64
# year_received               33358 non-null int64
# month_closed                33358 non-null int64
# year_closed                 33358 non-null int64
# command_at_incident         31814 non-null object
# rank_abbrev_incident        33358 non-null object
# rank_abbrev_now             33358 non-null object
# rank_now                    33358 non-null object
# rank_incident               33358 non-null object
# mos_ethnicity               33358 non-null object
# mos_gender                  33358 non-null object
# mos_age_incident            33358 non-null int64
# complainant_ethnicity       28894 non-null object
# complainant_gender          29163 non-null object
# complainant_age_incident    28546 non-null float64
# fado_type                   33358 non-null object
# allegation                  33357 non-null object
# precinct                    33334 non-null float64
# contact_reason              33159 non-null object
# outcome_description         33302 non-null object
# board_disposition           33358 non-null object
# dtypes: float64(2), int64(8), object(17)
# memory usage: 6.9+ MB

# %% [markdown]
# Later on we will determine whether 'complainant_age_incident' and 'precinct' should be of float or integer datatypes.
#
# Already we can see that there is missing data that we will have to deal with. Let's see the proportion of missing data for each column.

# %%
# Proportion of null values
df_raw.isna().sum()/len(df_raw)
# Out:
# unique_mos_id               0.000000
# first_name                  0.000000
# last_name                   0.000000
# command_now                 0.000000
# shield_no                   0.000000
# complaint_id                0.000000
# month_received              0.000000
# year_received               0.000000
# month_closed                0.000000
# year_closed                 0.000000
# command_at_incident         0.046286
# rank_abbrev_incident        0.000000
# rank_abbrev_now             0.000000
# rank_now                    0.000000
# rank_incident               0.000000
# mos_ethnicity               0.000000
# mos_gender                  0.000000
# mos_age_incident            0.000000
# complainant_ethnicity       0.133821
# complainant_gender          0.125757
# complainant_age_incident    0.144253
# fado_type                   0.000000
# allegation                  0.000030
# precinct                    0.000719
# contact_reason              0.005966
# outcome_description         0.001679
# board_disposition           0.000000
# dtype: float64

# %% [markdown]
# Let's get to it!

# %%
# Making a copy of df_raw to clean 
df_clean = df_raw.copy()

# %% [markdown]
# ### Let's start with **'outcome_description'**

# %%
df_clean['outcome_description'].value_counts(normalize=True)
# Out:
# No arrest made or summons issued        0.385022
# Arrest - other violation/crime          0.306168
# Summons - disorderly conduct            0.063600
# Summons - other violation/crime         0.058255
# Arrest - resisting arrest               0.047835
# Arrest - disorderly conduct             0.030419
# Arrest - assault (against a PO)         0.025584
# Moving violation summons issued         0.025194
# Arrest - OGA                            0.019488
# Other VTL violation summons issued      0.015945
# Parking summons issued                  0.008378
# Disorderly-Conduct/Arr/Summons          0.004114
# Arrest on Other Charge                  0.002432
# Traffic Summons Claimed or Issued       0.001772
# Juvenile Report                         0.001712
# Other Summons Claimed or Issued         0.001141
# Assault/Arrested                        0.001021
# Resisting Arrest/Arrested               0.000751
# Arrest - harrassment (against a PO)     0.000450
# Obstruct-Govt-Admin/Arrested            0.000300
# Harrassment/Arrested/Summons            0.000240
# Summons - harrassment (against a PO)    0.000150
# Summons - OGA                           0.000030
# Name: outcome_description, dtype: float64

# %% [markdown]
# We can see the most common (mode average) outcome description is that no arrest was made or summons issued.
#
# We could justify filling the missing cells with this average... However, we could opt to be totally truthful and describe the outcome as it is, which is "`Unknown`."

# %%
# Filling missing data with 'Unknown'
df_clean['outcome_description'] = df_clean['outcome_description'].fillna('Unknown')

# Sanity check
print(f"There are {df_clean['outcome_description'].isna().sum()} nulls.")

df_clean['outcome_description'].value_counts(normalize=True)
# Out:
# There are 0 nulls.
# No arrest made or summons issued        0.384376
# Arrest - other violation/crime          0.305654
# Summons - disorderly conduct            0.063493
# Summons - other violation/crime         0.058157
# Arrest - resisting arrest               0.047755
# Arrest - disorderly conduct             0.030368
# Arrest - assault (against a PO)         0.025541
# Moving violation summons issued         0.025151
# Arrest - OGA                            0.019456
# Other VTL violation summons issued      0.015918
# Parking summons issued                  0.008364
# Disorderly-Conduct/Arr/Summons          0.004107
# Arrest on Other Charge                  0.002428
# Traffic Summons Claimed or Issued       0.001769
# Juvenile Report                         0.001709
# Unknown                                 0.001679
# Other Summons Claimed or Issued         0.001139
# Assault/Arrested                        0.001019
# Resisting Arrest/Arrested               0.000749
# Arrest - harrassment (against a PO)     0.000450
# Obstruct-Govt-Admin/Arrested            0.000300
# Harrassment/Arrested/Summons            0.000240
# Summons - harrassment (against a PO)    0.000150
# Summons - OGA                           0.000030
# Name: outcome_description, dtype: float64

# %% [markdown]
# ### Dealing with missing data in **'contact_reason'**
#
# We will fill the missing data with "Unknown" again.

# %%
df_clean['contact_reason'].value_counts(normalize=True)
# Out:
# PD suspected C/V of violation/crime - street                  0.303930
# Other                                                         0.123767
# PD suspected C/V of violation/crime - auto                    0.089900
# PD suspected C/V of violation/crime - bldg                    0.076661
# Moving violation                                              0.059803
# Other violation of VTL                                        0.034380
# Report-dispute                                                0.032721
# Execution of search warrant                                   0.027534
# Report of other crime                                         0.027323
# Execution of arrest/bench warrant                             0.020598
# Parking violation                                             0.019150
# Report-domestic dispute                                       0.016979
# C/V intervened on behalf of/observed encounter w/3rd party    0.016285
# Report-gun possession/shots fired                             0.014838
# PD suspected C/V of violation/crime - subway                  0.011460
# Patrol Encounter                                              0.010917
# Report-noise/disturbance                                      0.010736
# Report-possession/sale of narcotics                           0.009590
# C/V requested investigation of crime                          0.009530
# EDP aided case                                                0.009439
# Traffic Incidents/Accident/Prk Violation                      0.006605
# Stop/Question/Frisk                                           0.006212
# Traffic accident                                              0.006032
# Others                                                        0.005700
# C/V telephoned PCT                                            0.005278
# C/V at PCT to obtain information                              0.005036
# Report of Crime Past/Present                                  0.004976
# Aided case                                                    0.004644
# C/V requested info from officer                               0.003378
# Dispute                                                       0.003136
# C/V at PCT to file complaint of crime                         0.003076
# CV already in custody                                         0.003016
# Arrest/Complainant                                            0.002202
# Vehicle Stop and Check                                        0.001538
# Parade/special event                                          0.001387
# Arrest/Not Complainant                                        0.001387
# C/V at PCT to retrieve property                               0.001206
# Summons/Complainant                                           0.001176
# PD auto checkpoint                                            0.001176
# Assist ACS or other agency                                    0.001176
# Report of Disturbance/Noise Complaint                         0.001086
# Regulatory inspection                                         0.001086
# Demonstration/protest                                         0.001056
# PD telephones CV                                              0.000543
# Complainant at Pct. to make a Cmpl/info                       0.000483
# EDP Aided Cases                                               0.000362
# Transit checkpoint                                            0.000332
# Telephone Call to Precinct/Command                            0.000332
# Aided Cases                                                   0.000302
# Demonstrations                                                0.000241
# Complainant Witnessing Incident                               0.000151
# No contact                                                    0.000090
# Victim Subject of Sex Crime                                   0.000060
# Name: contact_reason, dtype: float64

# %% [markdown]
# To tidy this up a bit:

# %%
contact_dict = {
    'Others' : 'Other',
    'Aided Cases' : 'Aided case',
    'EDP Aided Cases' : 'EDP aided case',
    'Demonstrations' : 'Demonstration/protest',
    'Traffic accident' : 'Traffic Incidents/Accident/Prk Violation',
    'Report of Disturbance/Noise Complaint' : 'Report-noise/disturbance'
}

df_clean['contact_reason'] = df_clean['contact_reason'].replace(contact_dict)

# Sanity check 
df_clean['contact_reason'].value_counts(normalize=True)
# Out:
# PD suspected C/V of violation/crime - street                  0.303930
# Other                                                         0.129467
# PD suspected C/V of violation/crime - auto                    0.089900
# PD suspected C/V of violation/crime - bldg                    0.076661
# Moving violation                                              0.059803
# Other violation of VTL                                        0.034380
# Report-dispute                                                0.032721
# Execution of search warrant                                   0.027534
# Report of other crime                                         0.027323
# Execution of arrest/bench warrant                             0.020598
# Parking violation                                             0.019150
# Report-domestic dispute                                       0.016979
# C/V intervened on behalf of/observed encounter w/3rd party    0.016285
# Report-gun possession/shots fired                             0.014838
# Traffic Incidents/Accident/Prk Violation                      0.012636
# Report-noise/disturbance                                      0.011822
# PD suspected C/V of violation/crime - subway                  0.011460
# Patrol Encounter                                              0.010917
# EDP aided case                                                0.009801
# Report-possession/sale of narcotics                           0.009590
# C/V requested investigation of crime                          0.009530
# Stop/Question/Frisk                                           0.006212
# C/V telephoned PCT                                            0.005278
# C/V at PCT to obtain information                              0.005036
# Report of Crime Past/Present                                  0.004976
# Aided case                                                    0.004946
# C/V requested info from officer                               0.003378
# Dispute                                                       0.003136
# C/V at PCT to file complaint of crime                         0.003076
# CV already in custody                                         0.003016
# Arrest/Complainant                                            0.002202
# Vehicle Stop and Check                                        0.001538
# Parade/special event                                          0.001387
# Arrest/Not Complainant                                        0.001387
# Demonstration/protest                                         0.001297
# C/V at PCT to retrieve property                               0.001206
# Assist ACS or other agency                                    0.001176
# PD auto checkpoint                                            0.001176
# Summons/Complainant                                           0.001176
# Regulatory inspection                                         0.001086
# PD telephones CV                                              0.000543
# Complainant at Pct. to make a Cmpl/info                       0.000483
# Telephone Call to Precinct/Command                            0.000332
# Transit checkpoint                                            0.000332
# Complainant Witnessing Incident                               0.000151
# No contact                                                    0.000090
# Victim Subject of Sex Crime                                   0.000060
# Name: contact_reason, dtype: float64

# %% [markdown]
# We could probably spend more time cleaning this up, but we have to move on.
#
# Let's fill the missing contact reasons with '`Unknown`.'

# %%
# Fill na with Unknown
df_clean['contact_reason'] = df_clean['contact_reason'].fillna('Unknown')

# Sanity check 
df_clean['contact_reason'].isna().any()
# Out:
# False

# %% [markdown]
# Great we can try and tackle the missing precincts now.
#
# ### Cleaning up the 'precinct' column

# %%
# Checking that all are whole numbers
df_clean['precinct'].apply(float.is_integer).all()
# Out:
# False

# %%
# Getting rows that returned False as being a whole number/integer
precinct_false_int = df_clean[~df_clean['precinct'].apply(float.is_integer)]

# Getting a proportion of null values
precinct_false_int['precinct'].isna().value_counts(normalize=True)
# Out:
# True    1.0
# Name: precinct, dtype: float64

# %%
# Display
precinct_false_int[['unique_mos_id','first_name', 'last_name','command_at_incident', 'command_now']]
# Out:
#        unique_mos_id first_name      last_name command_at_incident command_now
# 6602           18399    Douglas        Lansing             SOD T/U     D-E T/F
# 6806           18477       John         Acconi              DA QNS      DA QNS
# 7037           18561     Thomas     Mclaughlin             CENROBB     DB BXHM
# 9322           19561    Michael        Greaney             WARRSEC        DBQS
# 12780          21933     Tomasz            Fil              HWY 03      HWY 03
# 12781          21933     Tomasz            Fil              HWY 03      HWY 03
# 12782          21933     Tomasz            Fil              HWY 03      HWY 03
# 15702          23593    Anthony  Quagliariello             MTS DET      JT T/F
# 15703          23593    Anthony  Quagliariello             MTS DET      JT T/F
# 15704          23593    Anthony  Quagliariello             MTS DET      JT T/F
# 15705          23593    Anthony  Quagliariello             MTS DET      JT T/F
# 26077          35924      Jason         Garcia             WARRSEC     WARRSEC
# 26403          36019       John      Mccrossen             WARRSEC     WARRSEC
# 26404          36019       John      Mccrossen             WARRSEC     WARRSEC
# 26721          36140    Richard       Thompson             WARRSEC     WARRSEC
# 26730          36140    Richard       Thompson             WARRSEC     WARRSEC
# 26735          36140    Richard       Thompson             WARRSEC     WARRSEC
# 26736          36140    Richard       Thompson             WARRSEC     WARRSEC
# 28692           5281    Charles           Gove             047 DET     047 DET
# 28693           5281    Charles           Gove             047 DET     047 DET
# 29722           6301       Hugh      Mackenzie             052 PCT     052 PCT
# 29723           6301       Hugh      Mackenzie             052 PCT     052 PCT
# 30891           7694     Thomas      Mcdonnell             068 DET     068 DET
# 31956           8735    Barbara        Fischer             073 PCT     073 DET

# %% [markdown]
# MTS = Midtown South Precinct, so MTS will be added to precinct

# %%
df_clean.loc[15702:15705, 'precinct'] = "MTS"
df_clean.loc[28692:28693, 'precinct'] = 47
df_clean.loc[29722:29723, 'precinct'] = 52
df_clean.loc[30891, 'precinct'] = 68
df_clean.loc[31956, 'precinct'] = 73

# Sanity check
df_clean[df_clean['precinct'].isna()]
# Out:
#        unique_mos_id first_name   last_name command_now  shield_no  \
# 6602           18399    Douglas     Lansing     D-E T/F       6597
# 6806           18477       John      Acconi      DA QNS        394
# 7037           18561     Thomas  Mclaughlin     DB BXHM       5097
# 9322           19561    Michael     Greaney        DBQS       7490
# 12780          21933     Tomasz         Fil      HWY 03      21392
# 12781          21933     Tomasz         Fil      HWY 03      21392
# 12782          21933     Tomasz         Fil      HWY 03      21392
# 26077          35924      Jason      Garcia     WARRSEC       2362
# 26403          36019       John   Mccrossen     WARRSEC       6353
# 26404          36019       John   Mccrossen     WARRSEC       6353
# 26721          36140    Richard    Thompson     WARRSEC       5977
# 26730          36140    Richard    Thompson     WARRSEC       5977
# 26735          36140    Richard    Thompson     WARRSEC       5977
# 26736          36140    Richard    Thompson     WARRSEC       5977
#
#        complaint_id  month_received  year_received  month_closed  year_closed  \
# 6602           6236               3           2003             3         2004
# 6806          43400              10           2019             4         2020
# 7037          30178               2           2014            11         2014
# 9322          33535               9           2015             3         2016
# 12780         39202               3           2018            10         2018
# 12781         39202               3           2018            10         2018
# 12782         39202               3           2018            10         2018
# 26077         33647              10           2015             1         2016
# 26403         33535               9           2015             3         2016
# 26404         33535               9           2015             3         2016
# 26721         26999              10           2012             7         2013
# 26730         26999              10           2012             7         2013
# 26735         40991              11           2018             8         2019
# 26736         40991              11           2018             8         2019
#
#        ... mos_age_incident complainant_ethnicity complainant_gender  \
# 6602   ...               35                 Black               Male
# 6806   ...               49               Unknown             Female
# 7037   ...               41                   NaN                NaN
# 9322   ...               30                   NaN                NaN
# 12780  ...               36                 White               Male
# 12781  ...               36                 White               Male
# 12782  ...               36                 White               Male
# 26077  ...               43                 Black             Female
# 26403  ...               42                 Black               Male
# 26404  ...               42                   NaN                NaN
# 26721  ...               40                 White             Female
# 26730  ...               40                   NaN                NaN
# 26735  ...               47                 White             Female
# 26736  ...               47                   NaN                NaN
#
#       complainant_age_incident           fado_type  \
# 6602                      23.0               Force
# 6806                      58.0         Discourtesy
# 7037                       NaN  Abuse of Authority
# 9322                       NaN  Abuse of Authority
# 12780                     40.0         Discourtesy
# 12781                     40.0         Discourtesy
# 12782                     40.0  Abuse of Authority
# 26077                     30.0  Abuse of Authority
# 26403                     54.0  Abuse of Authority
# 26404                      NaN  Abuse of Authority
# 26721                     55.0  Abuse of Authority
# 26730                      NaN  Abuse of Authority
# 26735                     29.0  Abuse of Authority
# 26736                      NaN  Abuse of Authority
#
#                                   allegation precinct  \
# 6602                             Gun Pointed      NaN
# 6806                                    Word      NaN
# 7037        Premises entered and/or searched      NaN
# 9322        Premises entered and/or searched      NaN
# 12780                                   Word      NaN
# 12781                                   Word      NaN
# 12782                       Threat of arrest      NaN
# 26077       Premises entered and/or searched      NaN
# 26403  Refusal to provide name/shield number      NaN
# 26404       Premises entered and/or searched      NaN
# 26721  Refusal to provide name/shield number      NaN
# 26730       Premises entered and/or searched      NaN
# 26735         Refusal to show arrest warrant      NaN
# 26736                      Entry of Premises      NaN
#
#                                    contact_reason  \
# 6602                                        Other
# 6806                                        Other
# 7037   PD suspected C/V of violation/crime - bldg
# 9322            Execution of arrest/bench warrant
# 12780                            Moving violation
# 12781                            Moving violation
# 12782                            Moving violation
# 26077           Execution of arrest/bench warrant
# 26403           Execution of arrest/bench warrant
# 26404           Execution of arrest/bench warrant
# 26721                                       Other
# 26730                                       Other
# 26735           Execution of arrest/bench warrant
# 26736           Execution of arrest/bench warrant
#
#                     outcome_description  \
# 6602     Arrest - other violation/crime
# 6806   No arrest made or summons issued
# 7037     Arrest - other violation/crime
# 9322   No arrest made or summons issued
# 12780   Moving violation summons issued
# 12781   Moving violation summons issued
# 12782   Moving violation summons issued
# 26077  No arrest made or summons issued
# 26403  No arrest made or summons issued
# 26404  No arrest made or summons issued
# 26721  No arrest made or summons issued
# 26730  No arrest made or summons issued
# 26735    Arrest - other violation/crime
# 26736    Arrest - other violation/crime
#
#                               board_disposition
# 6602                                 Exonerated
# 6806   Substantiated (Command Lvl Instructions)
# 7037                            Unsubstantiated
# 9322       Substantiated (Command Discipline B)
# 12780                           Unsubstantiated
# 12781                           Unsubstantiated
# 12782                           Unsubstantiated
# 26077      Substantiated (Command Discipline B)
# 26403      Substantiated (Command Discipline A)
# 26404      Substantiated (Command Discipline B)
# 26721                           Unsubstantiated
# 26730                           Unsubstantiated
# 26735                                Exonerated
# 26736                                Exonerated
#
# [14 rows x 27 columns]

# %%
df_clean['precinct'] = df_clean['precinct'].fillna('Not Applicable')

# Sanity check 
df_clean['precinct'].isna().any()
# Out:
# False

# %% [markdown]
# No 0th precinct.

# %%
for i in df_clean[df_clean['precinct'] == 0].index:
    
    df_clean.loc[i, 'precinct'] = "Not Applicable"

# %% [markdown]
# Cleaning up the string

# %%
# To string
df_clean['precinct'] = df_clean['precinct'].astype(str)

# Get rid of float remnents
df_clean['precinct'] = df_clean['precinct'].map(lambda x: x.rstrip('.0'))

# Sanity check 
df_clean['precinct'].unique()
# Out:
# array(['78', '67', '79', '77', '81', '73', '9', '75', '12', '1', '25',
#        '11', '83', '46', '28', '68', '7', '72', '122', '113', '101', '13',
#        '71', '23', '112', '69', '32', '94', '63', '76', '52', '47', '62',
#        '42', '84', '115', '109', '5', '88', '14', '103', '107', '104',
#        '4', '108', '45', '18', '102', '114', '19', '2', '106', '105',
#        '17', '6', '34', '44', '48', '41', '43', '111', '49', '26', '3',
#        '33', '61', '123', '121', '66', '24', 'Not Applicable', '22',
#        'MTS'], dtype=object)

# %% [markdown]
# ### Cleaning up the 'complainant_age_incident' column

# %%
# Checking that all are whole numbers
df_raw['complainant_age_incident'].apply(float.is_integer).all()
# Out:
# False

# %% [markdown]
# Let's take a look at the non-integers:

# %%
# Getting rows that returned False as being a whole number/integer
age_false_int = df_raw[~df_raw['complainant_age_incident'].apply(float.is_integer)]

# Display
age_false_int
# Out:
#        unique_mos_id first_name last_name command_now  shield_no  \
# 68             10039     Willie   Johnson     079 DET       4446
# 72             10039     Willie   Johnson     079 DET       4446
# 75             10039     Willie   Johnson     079 DET       4446
# 81             10039     Willie   Johnson     079 DET       4446
# 82             10039     Willie   Johnson     079 DET       4446
# ...              ...        ...       ...         ...        ...
# 33276           9796     Steven   Rupnick     077 PCT      27055
# 33277           9796     Steven   Rupnick     077 PCT      27055
# 33278           9796     Steven   Rupnick     077 PCT      27055
# 33279           9796     Steven   Rupnick     077 PCT      27055
# 33311           9856     Daniel     Zollo     077 PCT       5627
#
#        complaint_id  month_received  year_received  month_closed  year_closed  \
# 68            14557              10           2007             3         2009
# 72            18085               4           2009             6         2010
# 75            18085               4           2009             6         2010
# 81            21823              10           2010             4         2011
# 82            21823              10           2010             4         2011
# ...             ...             ...            ...           ...          ...
# 33276         38128              10           2017            11         2018
# 33277         38128              10           2017            11         2018
# 33278         38128              10           2017            11         2018
# 33279         38128              10           2017            11         2018
# 33311         19009               9           2009             8         2010
#
#        ... mos_age_incident complainant_ethnicity complainant_gender  \
# 68     ...               36                   NaN                NaN
# 72     ...               37                   NaN                NaN
# 75     ...               37                   NaN                NaN
# 81     ...               38              Hispanic               Male
# 82     ...               38              Hispanic               Male
# ...    ...              ...                   ...                ...
# 33276  ...               27               Unknown               Male
# 33277  ...               27               Unknown               Male
# 33278  ...               27               Unknown      Not described
# 33279  ...               27               Unknown      Not described
# 33311  ...               43                   NaN                NaN
#
#       complainant_age_incident           fado_type  \
# 68                         NaN  Abuse of Authority
# 72                         NaN  Abuse of Authority
# 75                         NaN  Abuse of Authority
# 81                         NaN         Discourtesy
# 82                         NaN  Abuse of Authority
# ...                        ...                 ...
# 33276                      NaN  Abuse of Authority
# 33277                      NaN  Abuse of Authority
# 33278                      NaN  Abuse of Authority
# 33279                      NaN  Abuse of Authority
# 33311                      NaN  Abuse of Authority
#
#                                  allegation precinct  \
# 68         Premises entered and/or searched     73.0
# 72                                Gun Drawn     75.0
# 75         Premises entered and/or searched     75.0
# 81                                     Word     75.0
# 82     Threat of force (verbal or physical)     75.0
# ...                                     ...      ...
# 33276           Interference with recording     77.0
# 33277  Threat of force (verbal or physical)     77.0
# 33278  Threat of force (verbal or physical)     77.0
# 33279                      Threat of arrest     77.0
# 33311      Premises entered and/or searched     77.0
#
#                                      contact_reason  \
# 68                      Execution of search warrant
# 72                                            Other
# 75                                            Other
# 81                      Execution of search warrant
# 82                      Execution of search warrant
# ...                                             ...
# 33276  PD suspected C/V of violation/crime - street
# 33277  PD suspected C/V of violation/crime - street
# 33278  PD suspected C/V of violation/crime - street
# 33279  PD suspected C/V of violation/crime - street
# 33311    PD suspected C/V of violation/crime - bldg
#
#                     outcome_description                   board_disposition
# 68     No arrest made or summons issued                          Exonerated
# 72       Arrest - other violation/crime                          Exonerated
# 75       Arrest - other violation/crime             Substantiated (Charges)
# 81       Arrest - other violation/crime                     Unsubstantiated
# 82       Arrest - other violation/crime                     Unsubstantiated
# ...                                 ...                                 ...
# 33276    Arrest - other violation/crime                     Unsubstantiated
# 33277    Arrest - other violation/crime                     Unsubstantiated
# 33278    Arrest - other violation/crime                     Unsubstantiated
# 33279    Arrest - other violation/crime                     Unsubstantiated
# 33311   Summons - other violation/crime  Substantiated (Command Discipline)
#
# [4812 rows x 27 columns]

# %% [markdown]
# From what we can see above, it seems that the entries that were not whole numbers were null values.
#
# However, let's make sure.

# %%
# Getting a proportion of null values
age_false_int['complainant_age_incident'].isna().value_counts(normalize=True)
# Out:
# True    1.0
# Name: complainant_age_incident, dtype: float64

# %% [markdown]
# Yes, 100% of the entries that were not whole numbers were null values. Thus, 'complainant_age_incident' should be of `int` datatype.
#
# However, we will have to deal with the missing values first.
#
# Let's get a quick overview.

# %%
df_clean['complainant_age_incident'].describe()
# Out:
# count    28546.000000
# mean        32.484201
# std         28.408963
# min      -4301.000000
# 25%         23.000000
# 50%         30.000000
# 75%         41.000000
# max        101.000000
# Name: complainant_age_incident, dtype: float64

# %% [markdown]
# The minimum age doesn't make any sense. Anything less than 0 we will first set to NaN.

# %%
# If complainant_age_incident < 0 then change it to NaN
for i in df_clean[df_clean['complainant_age_incident'] <0]['complainant_age_incident'].index:
    df_clean.loc[i, 'complainant_age_incident'] = np.NaN
    
# Sanity check
df_clean['complainant_age_incident'].describe()
# Out:
# count    28540.000000
# mean        32.641906
# std         12.206667
# min          0.000000
# 25%         23.000000
# 50%         30.000000
# 75%         41.000000
# max        101.000000
# Name: complainant_age_incident, dtype: float64

# %% [markdown]
# Now that we've removed the impossible complainant ages (0 years also isn't ideal, but we'll move on) let's fill the remaining missing data with the median of the column.

# %%
df_clean['complainant_age_incident'].median()
# Out:
# 30.0

# %%
# Fill null values with the median 
df_clean['complainant_age_incident'] = df_clean['complainant_age_incident'].fillna(df_clean['complainant_age_incident'].median())

# Sanity check that there are no nulls
df_clean['complainant_age_incident'].isna().any()
# Out:
# False

# %%
df_clean['complainant_age_incident'].describe()
# Out:
# count    33358.000000
# mean        32.260327
# std         11.328886
# min          0.000000
# 25%         24.000000
# 50%         30.000000
# 75%         38.000000
# max        101.000000
# Name: complainant_age_incident, dtype: float64

# %% [markdown]
# Lastly, we will change the datatype to int.

# %%
# Changing to int datatype
df_clean['complainant_age_incident'] = df_clean['complainant_age_incident'].astype(int)

# Sanity check
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33358 entries, 0 to 33357
# Data columns (total 27 columns):
# unique_mos_id               33358 non-null int64
# first_name                  33358 non-null object
# last_name                   33358 non-null object
# command_now                 33358 non-null object
# shield_no                   33358 non-null int64
# complaint_id                33358 non-null int64
# month_received              33358 non-null int64
# year_received               33358 non-null int64
# month_closed                33358 non-null int64
# year_closed                 33358 non-null int64
# command_at_incident         31814 non-null object
# rank_abbrev_incident        33358 non-null object
# rank_abbrev_now             33358 non-null object
# rank_now                    33358 non-null object
# rank_incident               33358 non-null object
# mos_ethnicity               33358 non-null object
# mos_gender                  33358 non-null object
# mos_age_incident            33358 non-null int64
# complainant_ethnicity       28894 non-null object
# complainant_gender          29163 non-null object
# complainant_age_incident    33358 non-null int32
# fado_type                   33358 non-null object
# allegation                  33357 non-null object
# precinct                    33358 non-null object
# contact_reason              33358 non-null object
# outcome_description         33358 non-null object
# board_disposition           33358 non-null object
# dtypes: int32(1), int64(8), object(18)
# memory usage: 6.7+ MB

# %% [markdown]
# ### Dealing with missing data in 'complainant_ethnicity' and 'complainant_gender'

# %%
df_clean['complainant_ethnicity'].value_counts()
# Out:
# Black              17114
# Hispanic            6424
# White               2783
# Unknown             1041
# Other Race           677
# Asian                532
# Refused              259
# American Indian       64
# Name: complainant_ethnicity, dtype: int64

# %% [markdown]
# Although we don't know if the ethnicity data is missing because the complainant refused to share it, we do know that it is technically "`Unknown`."

# %%
# Fill missing data with Unknown
df_clean['complainant_ethnicity'] = df_clean['complainant_ethnicity'].fillna('Unknown')

# Sanity check 
df_clean['complainant_ethnicity'].isna().any()
# Out:
# False

# %% [markdown]
# Now the gender:

# %%
df_clean['complainant_gender'].value_counts()
# Out:
# Male                     24058
# Female                    5021
# Not described               57
# Transwoman (MTF)            20
# Transman (FTM)               5
# Gender non-conforming        2
# Name: complainant_gender, dtype: int64

# %% [markdown]
# We will fill missing gender with "not described."

# %%
# Missing data to "Not described" group
df_clean['complainant_gender'] = df_clean['complainant_gender'].fillna('Not described')

# Sanity check 
df_clean['complainant_gender'].isna().any()
# Out:
# False

# %% [markdown]
# ### Now 'command_at_incident'

# %%
df_clean[df_clean['command_at_incident'].isna()][['rank_incident','rank_abbrev_incident','precinct']]
# Out:
#         rank_incident rank_abbrev_incident precinct
# 271    Police Officer                  POM       73
# 272    Police Officer                  POM       73
# 340    Police Officer                   PO       79
# 702    Police Officer                  POM       83
# 899    Police Officer                   PO       77
# ...               ...                  ...      ...
# 32606  Police Officer                   PO       75
# 32607  Police Officer                   PO       75
# 32629  Police Officer                   PO       75
# 32936  Police Officer                   PO       75
# 32937  Police Officer                   PO       75
#
# [1544 rows x 3 columns]

# %%
command_nulls = df_clean[df_clean['command_at_incident'].isna()]

to_pct = command_nulls[(command_nulls['rank_incident'] == 'Police Officer') | 
                       (command_nulls['rank_incident'] == 'Sergeant') | 
                       (command_nulls['rank_incident'] == 'Captain') | 
                       (command_nulls['rank_incident'] == 'Lieutenant')].index

# Sanity check 
to_pct
# Out:
# Int64Index([  271,   272,   340,   702,   899,   900,   901,   902,   903,
#               904,
#             ...
#             32601, 32602, 32603, 32604, 32605, 32606, 32607, 32629, 32936,
#             32937],
#            dtype='int64', length=1504)

# %%
for i in to_pct:
    
    if (df_clean.loc[i, 'precinct'] == 'Not Applicable'):
        
        df_clean.loc[i, 'command_at_incident'] = 'Not Applicable'
    
    elif (int(df_clean.loc[i, 'precinct']) < 10):
        
        df_clean.loc[i, 'command_at_incident'] = '00' + str(int(df_clean.loc[i, 'precinct'])) + ' PCT'
    
    elif (int(df_clean.loc[i, 'precinct']) >= 10) & (int(df_clean.loc[i, 'precinct']) < 100):
        
        df_clean.loc[i, 'command_at_incident'] = '0' + str(int(df_clean.loc[i, 'precinct'])) + ' PCT'
    
    elif int(df_clean.loc[i, 'precinct']) >= 100:
        
        df_clean.loc[i, 'command_at_incident'] = str(int(df_clean.loc[i, 'precinct'])) + ' PCT'
        
    else:
        continue
        
# Sanity check
df_clean[df_clean['command_at_incident'].isna()][['rank_incident','rank_abbrev_incident','precinct']]
# Out:
#       rank_incident rank_abbrev_incident precinct
# 6216      Detective                  DT3        7
# 6217      Detective                  DT3        7
# 6218      Detective                  DT3        7
# 6219      Detective                  DT3        7
# 6522      Detective                  DET      114
# 6523      Detective                  DT3      114
# 6524      Detective                  DET      114
# 8016      Detective                  DET       23
# 8017      Detective                  DET       23
# 8569      Detective                  DET        7
# 8572      Detective                  DET        7
# 8573      Detective                  DET        7
# 8574      Detective                  DET        7
# 8575      Detective                  DT3       12
# 8668      Detective                  DET        7
# 8669      Detective                  DET        5
# 8670      Detective                  DET        5
# 8671      Detective                  DET        5
# 8672      Detective                  DET       67
# 8673      Detective                  DET       67
# 8733      Detective                  DT3      115
# 8734      Detective                  DT3      115
# 8735      Detective                  DT3      115
# 9373      Detective                  DET        1
# 9968      Detective                  DT1        1
# 9969      Detective                  DT3        9
# 9970      Detective                  DT3        9
# 15080     Detective                  DET       23
# 15081     Detective                  DET       23
# 15082     Detective                  DET       23
# 15083     Detective                  DET        3
# 15634     Detective                  DT3        3
# 15699     Detective                  DET       14
# 15700     Detective                  DET       14
# 19791     Detective                  DET       42
# 19793     Detective                  DET       43
# 20769     Detective                  DET       12
# 20770     Detective                  DET       12
# 25407     Detective                  DET       75
# 32386     Detective                  DET       75

# %%
det = df_clean[df_clean['command_at_incident'].isna()].index

# Sanity check 
det
# Out:
# Int64Index([ 6216,  6217,  6218,  6219,  6522,  6523,  6524,  8016,  8017,
#              8569,  8572,  8573,  8574,  8575,  8668,  8669,  8670,  8671,
#              8672,  8673,  8733,  8734,  8735,  9373,  9968,  9969,  9970,
#             15080, 15081, 15082, 15083, 15634, 15699, 15700, 19791, 19793,
#             20769, 20770, 25407, 32386],
#            dtype='int64')

# %%
for i in det:
    
    if (df_clean.loc[i, 'precinct'] == 'Not Applicable'):
        
        df_clean.loc[i, 'command_at_incident'] = 'Not Applicable'
    
    elif (int(df_clean.loc[i, 'precinct']) < 10):
        
        df_clean.loc[i, 'command_at_incident'] = '00' + str(int(df_clean.loc[i, 'precinct'])) + ' DET'
    
    elif (int(df_clean.loc[i, 'precinct']) >= 10) & (int(df_clean.loc[i, 'precinct']) < 100):
        
        df_clean.loc[i, 'command_at_incident'] = '0' + str(int(df_clean.loc[i, 'precinct'])) + ' DET'
    
    elif int(df_clean.loc[i, 'precinct']) >= 100:
        
        df_clean.loc[i, 'command_at_incident'] = str(int(df_clean.loc[i, 'precinct'])) + ' DET'
        
    else:
        continue
        
# Sanity check
df_clean['command_at_incident'].isna().any()
# Out:
# False

# %% [markdown]
# Let's get rid of any duplicate complaints first.

# %%
# Checking whether there are duplicated rows
df_clean.duplicated().any()
# Out:
# True

# %% [markdown]
# There are duplicated rows. How many?

# %%
# Getting a count of the duplicated rows 
print(f'There are {df_clean.duplicated().sum()} duplicate complaints.')
# Out:
# There are 633 duplicate complaints.

# %%
# Drop the duplicate rows from df_clean
df_clean = df_clean.drop_duplicates()

# Sanity check 
df_clean.duplicated().any()
# Out:
# False

# %% [markdown]
# Okay, let's take a look at the missing data again.

# %%
df_clean.isna().sum()/len(df_clean)
# Out:
# unique_mos_id               0.000000
# first_name                  0.000000
# last_name                   0.000000
# command_now                 0.000000
# shield_no                   0.000000
# complaint_id                0.000000
# month_received              0.000000
# year_received               0.000000
# month_closed                0.000000
# year_closed                 0.000000
# command_at_incident         0.000000
# rank_abbrev_incident        0.000000
# rank_abbrev_now             0.000000
# rank_now                    0.000000
# rank_incident               0.000000
# mos_ethnicity               0.000000
# mos_gender                  0.000000
# mos_age_incident            0.000000
# complainant_ethnicity       0.000000
# complainant_gender          0.000000
# complainant_age_incident    0.000000
# fado_type                   0.000000
# allegation                  0.000031
# precinct                    0.000000
# contact_reason              0.000000
# outcome_description         0.000000
# board_disposition           0.000000
# dtype: float64

# %% [markdown]
# ### Taking a look at `allegation` missing data

# %%
df_clean[df_clean['allegation'].isna()]
# Out:
#       unique_mos_id first_name last_name command_now  shield_no  complaint_id  \
# 3982          15188      Peter    Ievolo     120 PCT       1517           860
#
#       month_received  year_received  month_closed  year_closed  ...  \
# 3982               5           1989             5         1989  ...
#
#      mos_age_incident complainant_ethnicity complainant_gender  \
# 3982               31               Unknown      Not described
#
#      complainant_age_incident fado_type allegation precinct    contact_reason  \
# 3982                       30     Force        NaN        7  Patrol Encounter
#
#                    outcome_description board_disposition
# 3982  No arrest made or summons issued   Unsubstantiated
#
# [1 rows x 27 columns]

# %%
# Drop the one
df_clean = df_clean.dropna()

# Summary 
df_clean.describe()
# Out:
#        unique_mos_id     shield_no  complaint_id  month_received  \
# count   32724.000000  32724.000000  32724.000000    32724.000000
# mean    18161.045318   6450.167736  23916.864228        6.323310
# std      9584.620300   7941.179134  11855.535381        3.364952
# min         2.000000      0.000000    517.000000        1.000000
# 25%      9654.000000   1101.000000  13799.000000        3.000000
# 50%     19215.000000   3691.000000  25086.500000        6.000000
# 75%     25412.000000   7156.500000  34165.000000        9.000000
# max     36374.000000  31977.000000  43703.000000       12.000000
#
#        year_received  month_closed   year_closed  mos_age_incident  \
# count   32724.000000  32724.000000  32724.000000      32724.000000
# mean     2010.770260      6.472895   2011.573738         32.356955
# std         5.908341      3.343805      5.950295          6.032781
# min      1985.000000      1.000000   1985.000000         20.000000
# 25%      2007.000000      4.000000   2008.000000         28.000000
# 50%      2012.000000      6.000000   2013.000000         31.000000
# 75%      2015.000000      9.000000   2016.000000         36.000000
# max      2020.000000     12.000000   2020.000000         60.000000
#
#        complainant_age_incident
# count              32724.000000
# mean                  32.291621
# std                   11.363212
# min                    0.000000
# 25%                   24.000000
# 50%                   30.000000
# 75%                   38.000000
# max                  101.000000

# %% [markdown]
# Although we don't know if the ethnicity data is missing because the complainant refused to share it, we do know that it is technically "`Unknown`."

# %% [markdown]
# ## Repetitive Police Officer ranks

# %%
rank_dict = {
    'POM' : 'PO',
    'POF' : 'PO',
}

df_clean['rank_abbrev_now'] = df_clean['rank_abbrev_now'].replace(rank_dict)
df_clean['rank_abbrev_incident'] = df_clean['rank_abbrev_incident'].replace(rank_dict)

# Sanity check 
print(df_clean['rank_abbrev_now'].value_counts(normalize=True),'\n')
print(df_clean['rank_abbrev_incident'].value_counts(normalize=True))
# Out:
# PO     0.307847
# DT3    0.206943
# SGT    0.183138
# LT     0.084433
# DTS    0.038962
# SDS    0.036640
# DT2    0.032728
# CPT    0.021972
# LCD    0.019985
# DT1    0.019680
# SSA    0.013812
# DI     0.012712
# INS    0.006295
# LSA    0.006265
# DC     0.004645
# AC     0.002628
# CCC    0.000581
# COI    0.000428
# CD     0.000306
# Name: rank_abbrev_now, dtype: float64
#
# PO     0.674276
# SGT    0.171250
# DT3    0.081805
# LT     0.037954
# DTS    0.009870
# DT2    0.005928
# CPT    0.005409
# SDS    0.003759
# SSA    0.003148
# DI     0.002781
# DET    0.001253
# INS    0.000825
# LSA    0.000703
# DT1    0.000581
# LCD    0.000397
# DC     0.000061
# Name: rank_abbrev_incident, dtype: float64

# %% [markdown]
# ## Engineering a 'months_open' feature

# %%
df_clean[['month_received','year_received','month_closed','year_closed']]
# Out:
#        month_received  year_received  month_closed  year_closed
# 0                   7           2019             5         2020
# 1                  11           2011             8         2012
# 2                  11           2011             8         2012
# 3                   7           2012             9         2013
# 4                   8           2018             2         2019
# ...               ...            ...           ...          ...
# 33353               8           2016             2         2017
# 33354               8           2016             2         2017
# 33355               8           2016             2         2017
# 33356               8           2016             2         2017
# 33357               8           2016             2         2017
#
# [32724 rows x 4 columns]

# %%
df_clean['months_open'] = (12 - df_clean['month_received']) + (df_clean['year_closed']-1 - df_clean['year_received'])*12 + df_clean['month_closed']

# Check it out
df_clean[['month_received','year_received','month_closed','year_closed','months_open']]
# Out:
#        month_received  year_received  month_closed  year_closed  months_open
# 0                   7           2019             5         2020           10
# 1                  11           2011             8         2012            9
# 2                  11           2011             8         2012            9
# 3                   7           2012             9         2013           14
# 4                   8           2018             2         2019            6
# ...               ...            ...           ...          ...          ...
# 33353               8           2016             2         2017            6
# 33354               8           2016             2         2017            6
# 33355               8           2016             2         2017            6
# 33356               8           2016             2         2017            6
# 33357               8           2016             2         2017            6
#
# [32724 rows x 5 columns]

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32724 entries, 0 to 33357
# Data columns (total 28 columns):
# unique_mos_id               32724 non-null int64
# first_name                  32724 non-null object
# last_name                   32724 non-null object
# command_now                 32724 non-null object
# shield_no                   32724 non-null int64
# complaint_id                32724 non-null int64
# month_received              32724 non-null int64
# year_received               32724 non-null int64
# month_closed                32724 non-null int64
# year_closed                 32724 non-null int64
# command_at_incident         32724 non-null object
# rank_abbrev_incident        32724 non-null object
# rank_abbrev_now             32724 non-null object
# rank_now                    32724 non-null object
# rank_incident               32724 non-null object
# mos_ethnicity               32724 non-null object
# mos_gender                  32724 non-null object
# mos_age_incident            32724 non-null int64
# complainant_ethnicity       32724 non-null object
# complainant_gender          32724 non-null object
# complainant_age_incident    32724 non-null int32
# fado_type                   32724 non-null object
# allegation                  32724 non-null object
# precinct                    32724 non-null object
# contact_reason              32724 non-null object
# outcome_description         32724 non-null object
# board_disposition           32724 non-null object
# months_open                 32724 non-null int64
# dtypes: int32(1), int64(9), object(18)
# memory usage: 7.1+ MB

# %% [markdown]
# # NOTE: Officers with rank Lieutenant or above do not have shield numbers!
#
# https://en.wikipedia.org/wiki/New_York_City_Police_Department

# %%
df_clean[df_clean['shield_no']==0]['rank_now'].value_counts()
# Out:
# Lieutenant                3622
# Captain                    719
# Deputy Inspector           416
# Chiefs and other ranks     281
# Inspector                  206
# Name: rank_now, dtype: int64

# %%
df_clean.reset_index(drop=True).to_csv('cleaned_nypd_complaints.csv')

# %%
pd.read_csv('cleaned_nypd_complaints.csv', index_col=0)
# Out:
#        unique_mos_id first_name last_name command_now  shield_no  \
# 0              10004   Jonathan      Ruiz     078 PCT       8409
# 1              10007       John     Sears     078 PCT       5952
# 2              10007       John     Sears     078 PCT       5952
# 3              10007       John     Sears     078 PCT       5952
# 4              10009      Noemi    Sierra     078 PCT      24058
# ...              ...        ...       ...         ...        ...
# 32719           9992     Tomasz  Pulawski     078 PCT       2642
# 32720           9992     Tomasz  Pulawski     078 PCT       2642
# 32721           9992     Tomasz  Pulawski     078 PCT       2642
# 32722           9992     Tomasz  Pulawski     078 PCT       2642
# 32723           9992     Tomasz  Pulawski     078 PCT       2642
#
#        complaint_id  month_received  year_received  month_closed  year_closed  \
# 0             42835               7           2019             5         2020
# 1             24601              11           2011             8         2012
# 2             24601              11           2011             8         2012
# 3             26146               7           2012             9         2013
# 4             40253               8           2018             2         2019
# ...             ...             ...            ...           ...          ...
# 32719         35671               8           2016             2         2017
# 32720         35671               8           2016             2         2017
# 32721         35671               8           2016             2         2017
# 32722         35671               8           2016             2         2017
# 32723         35671               8           2016             2         2017
#
#        ... complainant_ethnicity complainant_gender complainant_age_incident  \
# 0      ...                 Black             Female                       38
# 1      ...                 Black               Male                       26
# 2      ...                 Black               Male                       26
# 3      ...                 Black               Male                       45
# 4      ...               Unknown      Not described                       16
# ...    ...                   ...                ...                      ...
# 32719  ...                 Asian               Male                       21
# 32720  ...                 Asian               Male                       21
# 32721  ...                 Asian               Male                       21
# 32722  ...                 Asian               Male                       21
# 32723  ...                 Asian               Male                       21
#
#                 fado_type                    allegation precinct  \
# 0      Abuse of Authority  Failure to provide RTKA card       78
# 1             Discourtesy                        Action       67
# 2      Offensive Language                          Race       67
# 3      Abuse of Authority                      Question       67
# 4                   Force                Physical force       67
# ...                   ...                           ...      ...
# 32719         Discourtesy                          Word       66
# 32720  Abuse of Authority   Interference with recording       66
# 32721  Abuse of Authority            Search (of person)       66
# 32722  Abuse of Authority                Vehicle search       66
# 32723  Abuse of Authority                         Frisk       66
#
#                                      contact_reason  \
# 0                           Report-domestic dispute
# 1                                  Moving violation
# 2                                  Moving violation
# 3      PD suspected C/V of violation/crime - street
# 4                                    Report-dispute
# ...                                             ...
# 32719                              Moving violation
# 32720                              Moving violation
# 32721                              Moving violation
# 32722                              Moving violation
# 32723                              Moving violation
#
#                     outcome_description  \
# 0      No arrest made or summons issued
# 1       Moving violation summons issued
# 2       Moving violation summons issued
# 3      No arrest made or summons issued
# 4        Arrest - other violation/crime
# ...                                 ...
# 32719   Moving violation summons issued
# 32720   Moving violation summons issued
# 32721   Moving violation summons issued
# 32722   Moving violation summons issued
# 32723   Moving violation summons issued
#
#                               board_disposition months_open
# 0      Substantiated (Command Lvl Instructions)          10
# 1                       Substantiated (Charges)           9
# 2                       Substantiated (Charges)           9
# 3                       Substantiated (Charges)          14
# 4          Substantiated (Command Discipline A)           6
# ...                                         ...         ...
# 32719                           Unsubstantiated           6
# 32720                           Unsubstantiated           6
# 32721       Substantiated (Formalized Training)           6
# 32722       Substantiated (Formalized Training)           6
# 32723       Substantiated (Formalized Training)           6
#
# [32724 rows x 28 columns]
